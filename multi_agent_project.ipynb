# %%
import os
folders = [
    'project',
    'project/agents',
    'project/tools',
    'project/memory',
    'project/core'
]
for f in folders:
    os.makedirs(f, exist_ok=True)
print('Directories created')
